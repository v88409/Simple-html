# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex638796/ITsGOLU_EXTRACTOR/blob/main/colab_deploy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
from IPython.display import clear_output

#@title <h1><b><font color=CRIMSON>🎓 𝗜𝗧𝗦𝗚𝗢𝗟𝗨 𝗘𝗫𝗧𝗥𝗔𝗖𝗧𝗢𝗥</font></b>
# @markdown <div><center><a href="https://github.com/Alex638796/ITsGOLU_EXTRACTOR"><img height="100" src="https://opengraph.githubassets.com/1/Alex638796/ITsGOLU_EXTRACTOR"></center></a></div>
# @markdown <br><center><h2><strong><font color=CRIMSON>Course Content Extractor Bot</font></strong></h2></center>
# @markdown <center><i>Polling-based — no public URL needed on Colab.</i></center>

# ── Repo settings ──
GITHUB_URL = "https://github.com/Alex638796/ITsGOLU_EXTRACTOR.git"  #@param {type:"string"}
BRANCH_NAME = "main"  #@param {type:"string"}

base_dir = './repo'

def clone_or_update_repo(repo_url, base_directory, branch_name):
    repo_name = os.path.basename(repo_url).replace('.git', '')
    project_dir = os.path.join(base_directory, repo_name)

    if os.path.exists(project_dir):
        print(f"Deleting existing repository at: {project_dir} ...")
        shutil.rmtree(project_dir)
        print("Deleted existing repository successfully!")

    print(f"Cloning repository from {repo_url} (branch: {branch_name})...")
    clone_cmd = f"git clone -b {branch_name} {repo_url} {project_dir}"
    os.system(clone_cmd)
    print("Repository cloned successfully!")

    return project_dir

project_dir = clone_or_update_repo(GITHUB_URL, base_dir, BRANCH_NAME)

try:
    print(f"Entering project directory: {os.path.basename(project_dir)}...")
    os.chdir(project_dir)
    print("Entered project directory successfully!")
except FileNotFoundError as e:
    print(f"Error: {e}")
    raise

clear_output()

# Install required dependencies
print("Installing required dependencies...")
# !pip install -q -r requirements.txt
print("All requirements installed successfully!")

#@markdown ### <font color=CRIMSON>🔑 Environment Variables — Mandatory</font>

API_ID = ""  #@param {type:"string"}
os.environ['API_ID'] = API_ID

API_HASH = ""  #@param {type:"string"}
os.environ['API_HASH'] = API_HASH

BOT_TOKEN = ""  #@param {type:"string"}
os.environ['BOT_TOKEN'] = BOT_TOKEN

BOT_USERNAME = ""  #@param {type:"string"}
os.environ['BOT_USERNAME'] = BOT_USERNAME

OWNER_ID = ""  #@param {type:"string"}
os.environ['OWNER_ID'] = OWNER_ID

CHANNEL_ID = ""  #@param {type:"string"}
os.environ['CHANNEL_ID'] = CHANNEL_ID

CHANNEL_ID2 = ""  #@param {type:"string"}
os.environ['CHANNEL_ID2'] = CHANNEL_ID2

MONGO_URL = ""  #@param {type:"string"}
os.environ['MONGO_URL'] = MONGO_URL

PREMIUM_LOGS = ""  #@param {type:"string"}
os.environ['PREMIUM_LOGS'] = PREMIUM_LOGS

#@markdown ### <font color=CRIMSON>⚙️ Environment Variables — Optional (khaali chhod sakte ho)</font>

SUDO_USERS = ""  #@param {type:"string"}
os.environ['SUDO_USERS'] = SUDO_USERS

THUMB_URL = "https://i.ibb.co/DPCmWSKV/1000003297-3.png"  #@param {type:"string"}
os.environ['THUMB_URL'] = THUMB_URL

clear_output()

# Run the bot (this will block and stream logs live — this cell keeps the
# Colab session alive automatically while it runs. To stop the bot, press
# the ■ stop button on this cell.)
RUN_COMMAND = "python3 run.py"
print(f"Running command: {RUN_COMMAND} ...")
# !{RUN_COMMAND}
print("Execution completed!")
